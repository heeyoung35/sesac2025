# %% [markdown]
# ### STT(Speech-to-Text)
# Whisper

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()
# 오디오 파일은 텍스트가 아닌 바이너리 데이터이므로, 'rb'(Read Binary)모드로 열어서 전송해야 한다.
with open("output.mp3", "rb") as f:
    transcriptions = client.audio.transcriptions.create(
        model="whisper-1",
        file=f
    )
    # print(transcriptions)
    print(transcriptions.text)
# Out:
# 내년 서울 아파트 입주 물량이 올해의 절반 수준으로 떨어질 전망이다. 전세 매물 감소와 전세의 월세화 등으로 임차인의 주거 비용이 올라가는 상황에서 내년 임차인의 주거 부담은 더욱 커질 것으로 보인다.
