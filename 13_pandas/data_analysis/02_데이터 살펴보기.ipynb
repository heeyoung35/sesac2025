# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터 불러오기: read_csv()

# %%
# 파일 불러오기
df = pd.read_csv("./data/seoul_park.csv")

# %% [markdown]
# #### data 폴더에 저장되어 있는 미세먼저 데이터를 불러와 변수 mm에 저장하세요

# %%
mm = pd.read_csv("./data/misemunji.csv")

# %% [markdown]
# ### 데이터 살펴보기 : head(), tail()

# %%
df.head() # 값 설정 안하면 기본적으로 5개의 첫 데이터를 볼 수 있다.

# %%
df.tail(10) # 술자를 입력하여 출력하는 데이터 갯수 지정 가능

# %% [markdown]
# ### 데이터 정보 확인: info()

# %%
df.info() # 데이터가 명 개의 값을 가지는지, 어떤 자료형으로 저장되어있는지 등 확인 가능

# %% [markdown]
# #### 컬럼 이름을 활용한 특정 컬럼 추출

# %%
df["청소년"]

# %%
#### 미세먼저 데이터 mm 에서 "초미세먼지" 컬럼 추출해서 변수 cho에 저장해보자
mm.head()
cho=mm["초미세먼저"]
cho

# %%
df["날씨"].info()

# %% [markdown]
# #### 데이터 숫자 세기:value_counts()

# %%
df["날씨"].value_counts()  # 컬럼에 어떤 값들이 몇 개씩 존재하는지 확인
